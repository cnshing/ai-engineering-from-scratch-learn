# %% [markdown]
# Timeit for Numpy

# %% [markdown]
# Install numpy dependencies first and verify

# %%
# !pip install numpy
import numpy as np

# %%
# %timeit np.random.randn(100000)
# Out:
# 2.94 ms ± 530 ns per loop (mean ± std. dev. of 7 runs, 100 loops each)
